# %%
##hello

# %%
# Artificial neural network |  | ep6-2 sentdex nnfs | Data visualization | graph for data
import nnfs
from nnfs.datasets import spiral_data
import matplotlib.pyplot as plt

# %%
nnfs.init()

X, y = spiral_data(samples=300, classes=3)

plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='brg')
plt.show()

# %%
print(f"X=\n{X[:5]} \ntype: {type(X)} \nsize: {X.size} \ndim: {X.ndim}")
# Out:
# X=
# [[0.         0.        ]
#  [0.00077394 0.0032537 ]
#  [0.00353186 0.00568051]
#  [0.00942509 0.00344059]
#  [0.01171941 0.0064517 ]]
# type: <class 'numpy.ndarray'>
# size: 1800
# dim: 2

# %%
X[5], X[5].ndim, X[5].size
# Out:
# (array([-0.00528276,  0.01586604], dtype=float32), 1, 2)

# %%
X[5, 1]
# Out:
# np.float32(0.015866043)

# %%
import numpy as np
rand  = 0.1 * np.random.randn(3, 4)
print(rand)
np.max(rand, 0)
# Out:
# [[-0.02890052 -0.19986396 -0.11460004  0.00470661]
#  [ 0.08245572  0.05311784 -0.0128242  -0.02717716]
#  [ 0.02171796  0.00782112  0.14045456  0.01464408]]
# array([0.08245572, 0.05311784, 0.14045456, 0.01464408], dtype=float32)
