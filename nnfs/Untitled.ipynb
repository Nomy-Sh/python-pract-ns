# %%
##hello

# %%
# Artificial neural network |  | ep6-2 sentdex nnfs | Data visualization | graph for data
import nnfs
from nnfs.datasets import spiral_data
import matplotlib.pyplot as plt

nnfs.init()


X, y = spiral_data(samples=100, classes=3)

plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='brg')
plt.show()

# %%
X[:4], type(X)
# Out:
# (array([[0.        , 0.        ],
#         [0.00299556, 0.00964661],
#         [0.01288097, 0.01556285],
#         [0.02997479, 0.0044481 ]], dtype=float32),
#  numpy.ndarray)

# %%
import numpy as np
rand  = 0.1 * np.random.randn(3, 4)
rand
np.max(0, rand)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 rand  = 0.1 * np.random.randn(3, 4)
#       3 rand
# ----> 4 np.max(0, rand)
#
# File /opt/anaconda3/envs/my_ai_env/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3164, in max(a, axis, out, keepdims, initial, where)
#    3052 @array_function_dispatch(_max_dispatcher)
#    3053 @set_module('numpy')
#    3054 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3055          where=np._NoValue):
#    3056     """
#    3057     Return the maximum of an array or maximum along an axis.
#    3058
#    (...)   3162     5
#    3163     """
# -> 3164     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3165                           keepdims=keepdims, initial=initial, where=where)
#
# File /opt/anaconda3/envs/my_ai_env/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: only integer scalar arrays can be converted to a scalar index
